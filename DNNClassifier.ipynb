# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
from urllib.request import urlopen

import numpy as np
import tensorflow as tf

# Data sets
IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

# If the training and test sets aren't stored locally, download them.
if not os.path.exists(IRIS_TRAINING):
  raw = urlopen(IRIS_TRAINING_URL).read()
  with open(IRIS_TRAINING, "wb") as f:
    f.write(raw)

if not os.path.exists(IRIS_TEST):
  raw = urlopen(IRIS_TEST_URL).read()
  with open(IRIS_TEST, "wb") as f:
    f.write(raw)

# Load datasets.
training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TRAINING,
    target_dtype=np.int,
    features_dtype=np.float32)
test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TEST,
    target_dtype=np.int,
    features_dtype=np.float32)

# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[10, 20, 10],
                                            n_classes=3,
                                            model_dir="/tmp/iris_model")
# Define the training inputs
def get_train_inputs():
  x = tf.constant(training_set.data)
  y = tf.constant(training_set.target)

  return x, y

# Fit model.
classifier.fit(input_fn=get_train_inputs, steps=2000)

# Define the test inputs
def get_test_inputs():
  x = tf.constant(test_set.data)
  y = tf.constant(test_set.target)

  return x, y

# Evaluate accuracy.
accuracy_score = classifier.evaluate(input_fn=get_test_inputs,
                                     steps=1)["accuracy"]

print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

# Classify two new flower samples.
def new_samples():
  return np.array(
    [[6.4, 3.2, 4.5, 1.5],
     [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)

predictions = list(classifier.predict(input_fn=new_samples))

print(
    "New Samples, Class Predictions:    {}\n"
    .format(predictions))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_tf_random_seed': None, '_task_type': None, '_master': '', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_environment': 'local', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1147e9ac8>, '_is_chief': True, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# }
# WARNING:tensorflow:From /Users/majid/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 4001 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0291557, step = 4001
# INFO:tensorflow:global_step/sec: 1191.48
# INFO:tensorflow:loss = 0.0277927, step = 4101
# INFO:tensorflow:global_step/sec: 1345.01
# INFO:tensorflow:loss = 0.0281225, step = 4201
# INFO:tensorflow:global_step/sec: 1333.78
# INFO:tensorflow:loss = 0.0273587, step = 4301
# INFO:tensorflow:global_step/sec: 1268.62
# INFO:tensorflow:loss = 0.0270013, step = 4401
# INFO:tensorflow:global_step/sec: 1311.87
# INFO:tensorflow:loss = 0.0273972, step = 4501
# INFO:tensorflow:global_step/sec: 1280.98
# INFO:tensorflow:loss = 0.0268518, step = 4601
# INFO:tensorflow:global_step/sec: 1290.56
# INFO:tensorflow:loss = 0.0269666, step = 4701
# INFO:tensorflow:global_step/sec: 1338.03
# INFO:tensorflow:loss = 0.0266971, step = 4801
# INFO:tensorflow:global_step/sec: 1309.64
# INFO:tensorflow:loss = 0.0264942, step = 4901
# INFO:tensorflow:global_step/sec: 1322.84
# INFO:tensorflow:loss = 0.026325, step = 5001
# INFO:tensorflow:global_step/sec: 1227.28
# INFO:tensorflow:loss = 0.0262155, step = 5101
# INFO:tensorflow:global_step/sec: 1329.87
# INFO:tensorflow:loss = 0.0259672, step = 5201
# INFO:tensorflow:global_step/sec: 1125.43
# INFO:tensorflow:loss = 0.025741, step = 5301
# INFO:tensorflow:global_step/sec: 1055.17
# INFO:tensorflow:loss = 0.0256301, step = 5401
# INFO:tensorflow:global_step/sec: 1053.08
# INFO:tensorflow:loss = 0.0254578, step = 5501
# INFO:tensorflow:global_step/sec: 1053.94
# INFO:tensorflow:loss = 0.0252436, step = 5601
# INFO:tensorflow:global_step/sec: 1017.81
# INFO:tensorflow:loss = 0.0250702, step = 5701
# INFO:tensorflow:global_step/sec: 1181.59
# INFO:tensorflow:loss = 0.0249677, step = 5801
# INFO:tensorflow:global_step/sec: 1027.94
# INFO:tensorflow:loss = 0.0248058, step = 5901
# INFO:tensorflow:Saving checkpoints for 6000 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.024299.
# WARNING:tensorflow:From /Users/majid/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-04-05-21:58:28
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-04-05-21:58:29
# INFO:tensorflow:Saving dict for global step 6000: accuracy = 0.966667, auc = 0.998333, global_step = 6000, loss = 0.109628
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
#
# Test Accuracy: 0.966667
#
# New Samples, Class Predictions:    [1, 1]

# %%
training_set.data.shape
# Out:
# (120, 4)
